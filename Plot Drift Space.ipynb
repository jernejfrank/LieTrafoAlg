# %%
import numpy as np
import pandas as pd
import sympy
from sympy.plotting import plot
from sympy import *
from operator import mul
from functools import reduce
from mpmath import fac
import functools
from sympy import init_printing
from sympy import series,cos

from IPython.display import display_latex
init_printing()

# %%
x,y,px,py,delta, L = symbols('x y px py d L')
xn = x + L * px/(sqrt((1+delta)**2 - px**2 - py**2))
yn = y + L * px/(sqrt((1+delta)**2 - px**2 - py**2))

# %%
xn
# Out:
#             L⋅px
# ─────────────────────────── + x
#    ________________________
#   ╱     2     2          2
# ╲╱  - px  - py  + (d + 1)

# %% [markdown]
# # In px expansion

# %%
f = xn.subs([(py,10e-05),(delta, 0)])

# %% [markdown]
# ## x = 10e-05

# %%
fy = xn.subs([(x,0),(px,10e-04),(delta, 0)])
yy1 = series(fy,py,x0=0,n=3).removeO()
yy1
# Out:
#                          2
# 0.000500000750000938⋅L⋅py  + 0.00100000050000038⋅L

# %%
y1 = series(f,px,x0=0,n=2).removeO()
y1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-043c4792d4d6> in <module>
# ----> 1 y1 = series(f,px,x0=0,n=2).removeO()
#       2 y1
#
# /usr/local/lib/python3.6/dist-packages/sympy/series/series.py in series(expr, x, x0, n, dir)
#      10     """
#      11     expr = sympify(expr)
# ---> 12     return expr.series(x, x0, n, dir)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in series(self, x, x0, n, dir, logx)
#    2728             # replace x with an x that has a positive assumption
#    2729             xpos = Dummy('x', positive=True, finite=True)
# -> 2730             rv = self.subs(x, xpos).series(xpos, x0, n, dir, logx=logx)
#    2731             if n is None:
#    2732                 return (s.subs(xpos, x) for s in rv)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in series(self, x, x0, n, dir, logx)
#    2775
#    2776             try:
# -> 2777                 return collect(s1, x) + o
#    2778             except NotImplementedError:
#    2779                 return s1 + o
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/decorators.py in binary_op_wrapper(self, other)
#     127                     if f is not None:
#     128                         return f(self)
# --> 129             return func(self, other)
#     130         return binary_op_wrapper
#     131     return priority_decorator
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in __add__(self, other)
#     129     @call_highest_priority('__radd__')
#     130     def __add__(self, other):
# --> 131         return Add(self, other)
#     132
#     133     @_sympifyit('other', NotImplemented)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      45             return args[0]
#      46
# ---> 47         c_part, nc_part, order_symbols = cls.flatten(args)
#      48         is_commutative = not nc_part
#      49         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/add.py in flatten(cls, seq)
#     259                 for o in order_factors:
#     260                     # x + O(x) -> O(x)
# --> 261                     if o.contains(t):
#     262                         t = None
#     263                         break
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/series/order.py in contains(self, expr)
#     405                         return rv
#     406
# --> 407         obj = self.func(expr, *self.args[1:])
#     408         return self.contains(obj)
#     409
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/series/order.py in __new__(cls, expr, *args, **kwargs)
#     219
#     220             elif expr:
# --> 221                 expr = expr.as_leading_term(*args)
#     222                 expr = expr.as_independent(*args, as_Add=False)[1]
#     223
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in as_leading_term(self, *symbols)
#    3011         obj = self._eval_as_leading_term(x)
#    3012         if obj is not None:
# -> 3013             return powsimp(obj, deep=True, combine='exp')
#    3014         raise NotImplementedError('as_leading_term(%s, %s)' % (self, x))
#    3015
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     141                 b, e = term.as_base_exp()
#     142                 if deep:
# --> 143                     b, e = [recurse(i) for i in [b, e]]
#     144                 if b.is_Pow or isinstance(b, exp):
#     145                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     141                 b, e = term.as_base_exp()
#     142                 if deep:
# --> 143                     b, e = [recurse(i) for i in [b, e]]
#     144                 if b.is_Pow or isinstance(b, exp):
#     145                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     141                 b, e = term.as_base_exp()
#     142                 if deep:
# --> 143                     b, e = [recurse(i) for i in [b, e]]
#     144                 if b.is_Pow or isinstance(b, exp):
#     145                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     141                 b, e = term.as_base_exp()
#     142                 if deep:
# --> 143                     b, e = [recurse(i) for i in [b, e]]
#     144                 if b.is_Pow or isinstance(b, exp):
#     145                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     119
#     120     if expr.is_Pow:
# --> 121         return recurse(expr*_y, deep=False)/_y
#     122
#     123     if not expr.is_Mul:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     160
#     161         # add up exponents of common bases
# --> 162         for b, e in ordered(iter(c_powers.items())):
#     163             # allow 2**x/4 -> 2**(x - 2); don't do this when b and e are
#     164             # Numbers since autoevaluation will undo it, e.g.
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     704                     raise ValueError(
#     705                         'not enough keys to break ties: %s' % u)
# --> 706         for v in d[k]:
#     707             yield v
#     708         d.pop(k)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     704                     raise ValueError(
#     705                         'not enough keys to break ties: %s' % u)
# --> 706         for v in d[k]:
#     707             yield v
#     708         d.pop(k)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     685         f = keys.pop(0)
#     686         for a in seq:
# --> 687             d[f(a)].append(a)
#     688     else:
#     689         if not default:
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/compatibility.py in default_sort_key(item, order)
#     552             unordered = False
#     553
# --> 554         args = [default_sort_key(arg, order=order) for arg in args]
#     555
#     556         if unordered:
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/compatibility.py in <listcomp>(.0)
#     552             unordered = False
#     553
# --> 554         args = [default_sort_key(arg, order=order) for arg in args]
#     555
#     556         if unordered:
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/compatibility.py in default_sort_key(item, order)
#     576
#     577     return (cls_index, 0, item.__class__.__name__
# --> 578             ), args, S.One.sort_key(), S.One
#     579
#     580
#
# KeyboardInterrupt:

# %%
y1 = series(f.subs(x,10e-05),px,x0=0,n=2).removeO()
y2 = series(f.subs(x,10e-05),px,x0=0,n=4).removeO()
y3 = series(f.subs(x,10e-05),px,x0=0,n=6).removeO()
y4 = series(f.subs(x,10e-05),px,x0=0,n=8).removeO()

y1 = y1.subs(px,10e-4)
y2 = y2.subs(px,10e-4)
y3 = y3.subs(px,10e-4)
y4 = y4.subs(px,10e-4)

p1=plot(y1,y2,y3,y4,(L,0,1),show=false)

p1[1].line_color = 'r'
p1[2].line_color = 'g'
p1[3].line_color = 'magenta'

p1.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-9dc8d3f0549f> in <module>
# ----> 1 y1 = series(f.subs(x,10e-05),px,x0=0,n=2).removeO()
#       2 y2 = series(f.subs(x,10e-05),px,x0=0,n=4).removeO()
#       3 y3 = series(f.subs(x,10e-05),px,x0=0,n=6).removeO()
#       4 y4 = series(f.subs(x,10e-05),px,x0=0,n=8).removeO()
#       5
#
# /usr/local/lib/python3.6/dist-packages/sympy/series/series.py in series(expr, x, x0, n, dir)
#      10     """
#      11     expr = sympify(expr)
# ---> 12     return expr.series(x, x0, n, dir)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in series(self, x, x0, n, dir, logx)
#    2728             # replace x with an x that has a positive assumption
#    2729             xpos = Dummy('x', positive=True, finite=True)
# -> 2730             rv = self.subs(x, xpos).series(xpos, x0, n, dir, logx=logx)
#    2731             if n is None:
#    2732                 return (s.subs(xpos, x) for s in rv)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in series(self, x, x0, n, dir, logx)
#    2775
#    2776             try:
# -> 2777                 return collect(s1, x) + o
#    2778             except NotImplementedError:
#    2779                 return s1 + o
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/decorators.py in binary_op_wrapper(self, other)
#     127                     if f is not None:
#     128                         return f(self)
# --> 129             return func(self, other)
#     130         return binary_op_wrapper
#     131     return priority_decorator
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in __add__(self, other)
#     129     @call_highest_priority('__radd__')
#     130     def __add__(self, other):
# --> 131         return Add(self, other)
#     132
#     133     @_sympifyit('other', NotImplemented)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      45             return args[0]
#      46
# ---> 47         c_part, nc_part, order_symbols = cls.flatten(args)
#      48         is_commutative = not nc_part
#      49         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/add.py in flatten(cls, seq)
#     259                 for o in order_factors:
#     260                     # x + O(x) -> O(x)
# --> 261                     if o.contains(t):
#     262                         t = None
#     263                         break
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/series/order.py in contains(self, expr)
#     405                         return rv
#     406
# --> 407         obj = self.func(expr, *self.args[1:])
#     408         return self.contains(obj)
#     409
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/series/order.py in __new__(cls, expr, *args, **kwargs)
#     219
#     220             elif expr:
# --> 221                 expr = expr.as_leading_term(*args)
#     222                 expr = expr.as_independent(*args, as_Add=False)[1]
#     223
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in as_leading_term(self, *symbols)
#    3011         obj = self._eval_as_leading_term(x)
#    3012         if obj is not None:
# -> 3013             return powsimp(obj, deep=True, combine='exp')
#    3014         raise NotImplementedError('as_leading_term(%s, %s)' % (self, x))
#    3015
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     116
#     117     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 118         expr = expr.func(*[recurse(w) for w in expr.args])
#     119
#     120     if expr.is_Pow:
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     107         _force = kwargs.get('force', force)
#     108         _measure = kwargs.get('measure', measure)
# --> 109         return powsimp(arg, _deep, _combine, _force, _measure)
#     110
#     111     expr = sympify(expr)
#
# /usr/local/lib/python3.6/dist-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     100
#     101     """
# --> 102     from sympy.matrices.expressions.matexpr import MatrixSymbol
#     103
#     104     def recurse(arg, **kwargs):
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %% [markdown]
# ## delta /neq 0

# %%
f = xn.subs([(py,1e-04),(delta, 0)])

# %%
y1 = series(f.subs(x,0),px,x0=0,n=2).removeO()
y2 = series(f.subs(x,0),px,x0=0,n=4).removeO()
y3 = series(f.subs(x,0),px,x0=0,n=6).removeO()
y4 = series(f.subs(x,0),px,x0=0,n=8).removeO()


p1=plot(y1,y2,y3,y4,(px,0,10e-4),show=false)

p1[1].line_color = 'r'
p1[2].line_color = 'g'
p1[3].line_color = 'magenta'

p1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-18a4e184a053> in <module>
#       5
#       6
# ----> 7 p1=plot(y1,y2,y3,y4,(px,0,10e-4),show=false)
#       8
#       9 p1[1].line_color = 'r'
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py in plot(*args, **kwargs)
#    1351             if len(free) > 1:
#    1352                 raise ValueError(
# -> 1353                     'The same variable should be used in all '
#    1354                     'univariate expressions being plotted.')
#    1355     x = free.pop() if free else Symbol('x')
#
# ValueError: The same variable should be used in all univariate expressions being plotted.

# %% [markdown]
# ## x = -10e-05

# %%
y1 = series(f.subs(x,-10e-05),px,x0=0,n=2).removeO()
y2 = series(f.subs(x,-10e-05),px,x0=0,n=4).removeO()
y3 = series(f.subs(x,-10e-05),px,x0=0,n=6).removeO()
y4 = series(f.subs(x,-10e-05),px,x0=0,n=8).removeO()


p1=plot(y1,y2,y3,y4,(px,0,1),show=false)

p1[1].line_color = 'r'
p1[2].line_color = 'g'
p1[3].line_color = 'magenta'

p1.show()

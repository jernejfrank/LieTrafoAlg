# %%
import numpy as np
import pandas as pd
import sympy
from sympy import *
from operator import mul
from functools import reduce
import mpmath as mp
from mpmath import fac
import functools
from sympy import init_printing
from sympy.core.decorators import _sympifyit, call_highest_priority
from IPython.display import display_latex
init_printing()

# %%
class LieOperator:
    '''
    Defined algebra for the Lie operator:
    Addition: Hamiltonian functions get added into a new Lie operator
    Multiplication: Poisson bracket gets applied
    CAUTION: NOT ASSOCIATIVE

    INPUT: Hamiltonian, generalized coordinates and momenta
    '''
    #Initialize the operator
    def __init__(self, ham, indep_coords, indep_mom):
        self._ham = ham 

        if not isinstance(indep_coords, list): #create list of coords
            indep_coords = [indep_coords]
        if not isinstance(indep_mom, list): #create list of momenta
            indep_mom = [indep_mom]
            
        #same number of coordinates and momenta have to be entered
        assert(len(indep_coords)==len(indep_mom)),'The number of coords and momenta is not the same'
        self._indep_coords = indep_coords
        self._indep_mom = indep_mom

    
    @property
    def ham(self):
        return self._ham
    
    @ham.setter
    def ham(self, other):
        self._ham = self._ham.subs(self.ham, other).doit()
        
    @property
    def indep_coords(self):
        return self._indep_coords
    
    @indep_coords.setter
    def indep_coords(self, other):
        self._indep_coords = other
        
    @property
    def indep_mom(self):
        return self._indep_mom
    
    @indep_mom.setter
    def indep_mom(self, other):
        self._indep_mom = other
    
    #Transform all variable to Lie Operators
    def MakeLieOperator(op):
        def CheckLieOperator(self,other):
            if not isinstance(other, LieOperator):
                other = LieOperator(other, self.indep_coords,self.indep_mom)

            
            return op(self,other)
        return CheckLieOperator
    
    #Algebraic properties 

    #Define Addition
    @MakeLieOperator
    def __add__(self,other):
        return LieOperator(self.ham + other.ham, self.indep_coords,self.indep_mom)

    @MakeLieOperator
    def __radd__(self,other):
        return LieOperator(other.ham + self.ham,self.indep_coords,self.indep_mom)
        
        
    #Define Multiplication
    @MakeLieOperator
    def __mul__(self, other):
        if S(other.ham).is_number:
            return 0
        else:
            return self.Poisson(other)
    
    
    def __rmul__(self,other):
        if S(other).is_number:
            return LieOperator(S(other)*self.ham, self.indep_coords,self.indep_mom)
        else:
            if not isinstance(other, LieOperator):
                other = LieOperator(other, self.indep_coords,self.indep_mom)
            return other.Poisson(self)
    
    #Calcualte Poisson bracket with input function
    def Poisson(self,other):
        h = 0
        print('In Poisson Bracket ---------------')
        print(self.ham)
        print(other.ham)
        for qi,pi in zip(self.indep_coords,self.indep_mom):
            h += self.ham.diff(qi) * other.ham.diff(pi) 
            print('Breaks down after first derivative')
            h -= self.ham.diff(pi) * other.ham.diff(qi)

        return LieOperator(h,self.indep_coords,self.indep_mom)

# %%
class LieMap(LieOperator):
    '''
    Defined algebra for the Lie Map:
    Inherits the structure of the Lie Operator
    Addition: Lie maps get added into a new Lie map
    Multiplication: Baker-Cambell-Hausdorff Formula is used 
    CAUTION: NOT ASSOCIATIVE

    INPUT: Hamiltonian, generalized coordinates and momenta, ExpPower, BCHPower
    ExpPower: cutoff for the exponential function
    BCHPower: cutoff for the Baker-Cambell-Hausdorff series
    
    For operations the higher power of the two elements will be selected
    '''
    
    def __init__(self, ham, indep_coords, indep_mom, ExpPower=6,BCHPower=2):
        super().__init__(ham, indep_coords, indep_mom)
        self.ExpN = ExpPower
        self.BCHN = BCHPower
        
    #Define addition
    def __add__(self,other):
        if not self.__class__ == other.__class__:
            print('Error: Both operators have to be Lie maps.')
        else:
            return LieMap(self.ham + other.ham, 
                          self.indep_coords,
                          self.indep_mom,
                          max(self.ExpN,other.ExpN),
                          max(self.BCHN,other.BCHN))

    def __radd__(self,other):
        if not self.__class__ == other.__class__:
            print('Error: Both operators have to be Lie maps.')
        else:
            return LieMap(other.ham + self.ham, 
                          self.indep_coords,
                          self.indep_mom,
                          max(self.ExpN,other.ExpN),
                          max(self.BCHN,other.BCHN))
    
    
    #Define Multiplication
    '''
    Multiplication:
    1) Lie Map * Lie Map :  Application of the BCH series with cutoff
    2) Lie Map * Variable : Application of the exponential function cutoff
        to the variable
    '''
    def __mul__(self, other):
        if self.__class__ == other.__class__:
            return LieMap(self.BCH(other,max(self.BCHN,other.BCHN)),
                          self.indep_coords,
                          self.indep_mom,
                          max(self.ExpN,other.ExpN),
                          max(self.BCHN,other.BCHN))
        else:
            return self.exp(other,self.ExpN)
    

    def __rmul__(self,other):
        if not isinstance(other, LieMap):
            print('Illegal operation: Right operator is not a Lie Map.')
            return
        return LieMap(other.BCH(self,max(self.BCHN,other.BCHN)),
                          self.indep_coords,
                          self.indep_mom,
                          max(self.ExpN,other.ExpN),
                          max(self.BCHN,other.BCHN))
    
    #Exponential map applied to Lie Operator
    #Successively apply Poisson bracket to input function to the input cutoff
    def ExpPowerLieBracket(self, other, power):
        s = 0
        op1 = LieOperator(self.ham, self.indep_coords,self.indep_mom)
#         op2 = LieOperator(other.ham, other.indep_coords,other.indep_mom)
        
        if power > 0:
            h = op1.__mul__(other)
            
            for s in range(1,power):
                h = op1.__mul__(h)
                
        else:
            h = other
        return h
    
    
    #Calculate the exponential map of the Lie operator to the input cutoff
    def exp(self,other,power):
        s = 0
        for i in range(power+1):
            s += sympy.Rational(1,factorial(i))*self.ExpPowerLieBracket(other,i)
        return s       
    
    
    
    #BCH Multiplication
    def np(self,n):
        F = sympy.Matrix(np.zeros((n+1,n+1)))
        for i in range(n+1):
            for j in range(n+1):
                if (j-i)>=0:
                    F[i,j] = sympy.Rational(1,int(fac(j-i))) # keep it rational !!!!



        G = sympy.Matrix(np.zeros((n+1,n+1)))
        for i in range(n+1):
            for j in range(n+1):
                if (j-i)>=0:
                    if i==j:
                        sigprod = 1
                    else:
                        l = sympy.symbols('s{}:{}'.format(i,j))
                        sigprod = reduce(sympy.Mul,l)
                    G[i,j] = sympy.Mul(sympy.Rational(1,int(np.math.factorial(j-i))),sigprod, evaluate=False)



        qthpower = sympy.Matrix(np.eye(n+1))

        FGm1 = sympy.nsimplify(F*G - qthpower)

        FGm1


        summ = 0

        for q in range(1,n+1):
            qthpower = sympy.nsimplify(sympy.MatMul(qthpower, FGm1, evaluate=False))

            summ += sympy.nsimplify((-1)**(q-1)/q * qthpower)[0,n] # q-1 because mathematica starts at 1 and not 0, there for sign change

        return sympy.expand(summ)

    def translated(self,other,n):
        l = sympy.symbols('s{}:{}'.format(0,n))
        temp = reduce(functools.partial(sympy.Mul,evaluate=False),[k*k for k in l])
        temp = sympy.expand(sympy.Mul(temp, self.np(n), evaluate=False),evaluate=False)
        with sympy.evaluate(False):
            ln = sympy.symbols('r{}:{}'.format(0,n), commutative=False)
            for i, s in enumerate(l):
                temp = temp.subs(l[i],ln[i])
            for i in range(n):
                _f = sympy.Symbol('f',commutative=False)
                _g = sympy.Symbol('g',commutative=False)
                temp = temp.subs(ln[i]**3,_g)
                temp = temp.subs(ln[i]**2,_f)
                temp = temp.subs(_g**0,1)

            op1 = LieOperator(self.ham,self.indep_coords,self.indep_mom)
            op2 = LieOperator(other.ham,other.indep_coords,other.indep_mom)
            
            
            #NEED TO WRITE THE FUNCTIONS TO RELATE NORMAL SYMBOLS TO LIE OPERATORS
            print('translated domain')
#             temp = temp.subs(_f,op1.ham)
#             temp = temp.subs(_g,op2.ham)

            temp = temp.replace(Mul, lambda *args: self.PoissonMultiplication(op1,op2,*args))
            print('ended substituting multiplication --------------')
            print(temp)
            print(type(temp))
            temp = temp.replace(Add, lambda *args: self.PoissonAddition(op1,op2,*args))
            
#             print('Checking temp')
#             print(temp)
#             print(type(temp))
#             temp = LieOperator(temp.ham.subs(f,op1.ham),self.indep_coords,self.indep_mom)
#             print('Checking temp after f subs')
#             print(temp)
#             print(type(temp))
#             temp = LieOperator(temp.ham.subs(g,op2.ham),self.indep_coords,self.indep_mom)
            
#             print('Checking temp after g subs')
            print('End of translated domain')
            
        return temp
    
    def PoissonMultiplication(self,op1,op2,*args):
        print('jumped into Poisson Multiplication')
        _f = sympy.Symbol('f',commutative=False)
        _g = sympy.Symbol('g',commutative=False)
#         if not isinstance(args[-1], LieOperator):
#             h = LieOperator(args[-1],self.indep_coords,self.indep_mom)
#         else:
#             h = args[-1]
        print('fine until assigning operators')
        if args[-1] == _f:
            h = op1
        elif args[-1] == _g:
            h = op2
        else:
            print('Expression does not start with an operator...')
            h = 1
        
        print(args[-1] == _f)
        print(args[-1] == _g)
               
        for op in args[-2::-1]:
            print("Looping thorugh args---------------")
            print(op)
            if S(op).is_number:
                print('Number recognized for', op)
                h = op * h
            else:
#                 if not isinstance(op, LieOperator):
#                     op = LieOperator(op,self.indep_coords,self.indep_mom)
                print(op == _f)
                print(op == _g)
                print(h)
                print(op1)
                print(op2)
                if op == _f:
                    h = op1.__mul__(h)
                elif op == _g:
                    h = op2.__mul__(h)
                else:
                    print('We have more than just f and g, namely', op)
#                 h = h.Poisson(op)


        
#         h = n * h
        print(h.ham)
        return h.ham
    
    def PoissonAddition(self,op1,op2,*args):
        print('jumped into Poisson Addition')
        h = 0
        print(args)
        _f = sympy.Symbol('f',commutative=False)
        _g = sympy.Symbol('g',commutative=False)
        
        if _f in args or _g in args:
            for op in args:
                if op == _f:
                    h = h + op1
                elif op == _g:
                    h = h + op2
                else:
                    print(op)
                    h = h + op
        else:
            for arg in args:
                if not isinstance(arg, LieOperator):
                    _temp = LieOperator(arg,self.indep_coords,self.indep_mom)
                h = h + _temp
        
        
        print(h)
        print(type(h))
        return h
    
    def BCH(self,other,n):
        s = 0
        for i in range(1,n+1):
            print('BCH Loop 1')
            print(s)
            print(type(s))
            print('BCH Loop 2')
            s+= (self.translated(other, i)).ham
        return LieMap(s,self.indep_coords,self.indep_mom)

# %%
x, p, delta = sympy.symbols('x p d')
H = sympy.Function('H1', commutative=False)(x,p)
f = sympy.Function('H2', commutative=False)(x,p)
g = sympy.Function('H3', commutative=False)(x,p)
W = x**2 + p**2
Z = - sympy.sqrt((1+delta)**2 - p**2)
la = LieOperator(H,x,p)
lb = LieOperator(g,x,p)
lc = LieOperator(f,x,p)
ma = LieMap(H,x,p,2,2)
mb = LieMap(g,x,p,3,3)
mc = LieMap(f,x,p,2,3)

mw = LieMap(W,x,p,2,2)
mz = LieMap(Z,x,p,2,2)

# %%
diff(H,x)
# Out:
# ∂
# ──(H₁(x, p))
# ∂x

# %%
(la*lb).ham
# Out:
# In Poisson Bracket ---------------
# H1(x, p)
# H3(x, p)
# Breaks down after first derivative
#   ∂            ∂              ∂            ∂
# - ──(H₁(x, p))⋅──(H₃(x, p)) + ──(H₁(x, p))⋅──(H₃(x, p))
#   ∂p           ∂x             ∂x           ∂p

# %%
diff(H,x)
# Out:
#              ⎛⎧x  for 0 = 1⎞
# ∂            ⎜⎪            ⎟
# ──(H₁(x, p))⋅⎜⎨1  for 1 = 1⎟
# ∂x           ⎜⎪            ⎟
#              ⎝⎩0  otherwise⎠

# %%
ma*mb
# Out:
# BCH Loop 1
# 0
# <class 'int'>
# BCH Loop 2
# translated domain
# ended substituting multiplication --------------
# f + g
# <class 'sympy.core.add.Add'>
# jumped into Poisson Addition
# (f, g)
# <__main__.LieOperator object at 0x7f13e5f9ccc0>
# <class '__main__.LieOperator'>
# End of translated domain
# BCH Loop 1
# H1(x, p) + H3(x, p)
# <class 'sympy.core.add.Add'>
# BCH Loop 2
# translated domain
# jumped into Poisson Multiplication
# fine until assigning operators
# False
# True
# Looping thorugh args---------------
# f
# True
# False
# <__main__.LieOperator object at 0x7f13e5f9c3c8>
# <__main__.LieOperator object at 0x7f13e5fabf98>
# <__main__.LieOperator object at 0x7f13e5f9c3c8>
# In Poisson Bracket ---------------
# H1(x, p)
# H3(x, p)
# Breaks down after first derivative
# Looping thorugh args---------------
# 1/2
# Number recognized for 1/2
# (-Derivative(H1(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))*Derivative(H3(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)) + (Derivative(H1(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))*(Derivative(H3(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))))/2
# jumped into Poisson Multiplication
# fine until assigning operators
# True
# False
# Looping thorugh args---------------
# g
# False
# True
# <__main__.LieOperator object at 0x7f13e5fabf98>
# <__main__.LieOperator object at 0x7f13e5fabf98>
# <__main__.LieOperator object at 0x7f13e5f9c3c8>
# In Poisson Bracket ---------------
# H3(x, p)
# H1(x, p)
# Breaks down after first derivative
# Looping thorugh args---------------
# -1/2
# Number recognized for -1/2
# -(-Derivative(H3(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))*Derivative(H1(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)) + (Derivative(H3(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))*(Derivative(H1(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))))/2
# ended substituting multiplication --------------
# (-Derivative(H1(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))*Derivative(H3(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)) + (Derivative(H1(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))*(Derivative(H3(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))))/2 - (-Derivative(H3(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))*Derivative(H1(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)) + (Derivative(H3(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))*(Derivative(H1(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))))/2
# <class 'sympy.core.add.Add'>
# jumped into Poisson Addition
# ((Derivative(H1(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))*(Derivative(H3(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))), -Derivative(H1(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))*Derivative(H3(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))
# <__main__.LieOperator object at 0x7f13e5fc2dd8>
# <class '__main__.LieOperator'>
# jumped into Poisson Addition
# ((Derivative(H3(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))*(Derivative(H1(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))), -Derivative(H3(x, p), p)*Piecewise((p, Eq(0, 1)), (1, Eq(1, 1)), (0, True))*Derivative(H1(x, p), x)*Piecewise((x, Eq(0, 1)), (1, Eq(1, 1)), (0, True)))
# <__main__.LieOperator object at 0x7f13e5fc2898>
# <class '__main__.LieOperator'>
# jumped into Poisson Addition
# (_Dummy_250/2, -_Dummy_251/2)
# <__main__.LieOperator object at 0x7f13e5fc21d0>
# <class '__main__.LieOperator'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9f876c6b4b78> in <module>
# ----> 1 ma*mb
#
# <ipython-input-3-41c9f5ce0d99> in __mul__(self, other)
#      50     def __mul__(self, other):
#      51         if self.__class__ == other.__class__:
# ---> 52             return LieMap(self.BCH(other,max(self.BCHN,other.BCHN)),
#      53                           self.indep_coords,
#      54                           self.indep_mom,
#
# <ipython-input-3-41c9f5ce0d99> in BCH(self, other, n)
#     261             print(type(s))
#     262             print('BCH Loop 2')
# --> 263             s+= (self.translated(other, i)).ham
#     264         return LieMap(s,self.indep_coords,self.indep_mom)
#
# <ipython-input-3-41c9f5ce0d99> in translated(self, other, n)
#     163             print(temp)
#     164             print(type(temp))
# --> 165             temp = temp.replace(Add, lambda *args: self.PoissonAddition(op1,op2,*args))
#     166
#     167 #             print('Checking temp')
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/basic.py in replace(self, query, value, map, simultaneous, exact)
#    1488             for o, n in mask:
#    1489                 r = {o: n}
# -> 1490                 rv = rv.xreplace(r)
#    1491
#    1492         if not map:
#
# AttributeError: 'LieOperator' object has no attribute 'xreplace'

# %%
(la*lb).ham

# %%
la + lb

# %%
2 + la

# %%
la + 2

# %%
(2*la).ham

# %%
la*2

# %%
(p*la).ham

# %%
(la*p).ham

# %%
(ma + mb).ham

# %%
(mb + ma).ham

# %%
ma + x

# %%
x + ma

# %%
(ma*x).ham

# %%
(ma*g).ham

# %%
g*ma
